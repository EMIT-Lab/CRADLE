# %%
import numpy as np 
import pandas as pd 
from pandas import DataFrame

import seaborn as sns
import matplotlib 
from matplotlib import pyplot as plt

matplotlib.rcParams.update({'font.size': 30})
from IPython.display import clear_output

# %%
df = pd.read_csv('D:/project/手性金纳米颗粒/AI-education/code/85/raw_data.csv')
df
# Out:
#                         DOI              method   metal  \
# 0         10.1021/cm3033725  one-pot reduction     gold
# 1                       NaN  one-pot reduction     gold
# 2                       NaN  one-pot reduction   silver
# 3                       NaN  one-pot reduction   silver
# 4    10.1002/adfm.201001120  one-pot reduction     gold
# ..                      ...                 ...     ...
# 196                     NaN  one-pot reduction   silver
# 197       10.1021/la703351p  one-pot reduction   silver
# 198                     NaN  one-pot reduction   silver
# 199                     NaN  one-pot reduction   silver
# 200                     NaN  one-pot reduction   silver
#
#                    metal_source  metal_amount_mmol               ligand  \
# 0    Tetrachloroauric(III) acid              0.132  N-acetyl-L-cysteine
# 1    Tetrachloroauric(III) acid              0.132  N-acetyl-L-cysteine
# 2                silver nitrate              0.870          glutathione
# ...

# %%
df_aug = pd.read_csv('dataset_augmented_all.csv')
df_aug
# Out:
#      Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  atomic_number  radius_pm  \
# 0               0             0           0        0.90070  -0.626518
# 1               1             1           1        0.90070  -0.626518
# 2               2             2           2       -1.03686  -0.252283
# 3               3             3           3       -1.03686  -0.252283
# 4               4             4           4        0.90070  -0.626518
# ..            ...           ...         ...            ...        ...
# 196           196           196         196       -1.03686  -0.252283
# 197           197           197         197       -1.03686  -0.252283
# 198           198           198         198       -1.03686  -0.252283
# 199           199           199         199       -1.03686  -0.252283
# 200           200           200         200       -1.03686  -0.252283
#
#      oxid_state  relativistic  metal_amount_mmol  num of group    spcaer  ...  \
# ...

# %% [markdown]
# ### Temperature

# %%
temp = pd.unique(df['temp_c'])
print(df['temp_c'].value_counts())
# Out:
# temp_c
# 25     141
# 0       28
# 100     12
# 30       4
# 80       3
# 50       2
# 95       2
# 37       2
# 110      1
# 60       1
# 28       1
# 45       1
# 300      1
# 70       1
# 43       1
# Name: count, dtype: int64

# %%
a4_dims = (9.8, 6)
fig, ax = plt.subplots(figsize=a4_dims)
ax = sns.violinplot(data=df['temp_c'],inner=None, color='0.85')
ax = sns.swarmplot (data=df['temp_c'], color="orange", edgecolor="gray", size=6.5)
fig.savefig('temp.png', transparent=True)
# Out:
# C:\Users\yello\AppData\Local\Temp\ipykernel_33144\3210603980.py:4: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   ax = sns.swarmplot (data=df['temp_c'], color="orange", edgecolor="gray", size=6.5)
# d:\app\Anaconda3\envs\drug\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 36.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# d:\app\Anaconda3\envs\drug\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 40.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ### Size

# %%
a4_dims = (25, 8)

fig, axs = plt.subplots(ncols=2, figsize=a4_dims)
fig.suptitle('Size', fontsize=60)

datasets=(df, df_aug)
i=0
titles=('Initial dataset', 'Final dataset')
for dataset in datasets :

    size= dataset.loc[dataset['size_nm'] != "None"]
    d=size['size_nm'].astype(float).tolist()
    sns.violinplot(data=d, inner=None, color='0.9', ax=axs[i]).set(title=titles[i])
    sns.swarmplot (data=d, color="palevioletred", edgecolor="gray", size=9, ax=axs[i])
    i=+1 

fig.savefig('size.png', transparent=True)
# Out:
# C:\Users\yello\AppData\Local\Temp\ipykernel_33144\2289970881.py:14: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.swarmplot (data=d, color="palevioletred", edgecolor="gray", size=9, ax=axs[i])
# d:\app\Anaconda3\envs\drug\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 18.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\yello\AppData\Local\Temp\ipykernel_33144\2289970881.py:14: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.swarmplot (data=d, color="palevioletred", edgecolor="gray", size=9, ax=axs[i])
# d:\app\Anaconda3\envs\drug\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 24.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
# ...

# %% [markdown]
# ### Absorption

# %%
a4_dims = (25, 8)

fig, axs = plt.subplots(ncols=2, figsize=a4_dims)
fig.suptitle('Absorption', fontsize=60)

datasets=(df, df_aug)
i=0
titles=('Initial dataset', 'Final dataset')
for dataset in datasets :

    Abs = dataset.loc[dataset['Abs_nm'] != "None"]
    e=Abs['Abs_nm'].astype(float).tolist()
    sns.violinplot(data=e, inner=None, color='0.9', ax=axs[i]).set(title=titles[i])
    sns.swarmplot (data=e, color="steelblue", edgecolor="gray", size=9, ax=axs[i])
    i=+1 

fig.savefig('Abs.png', transparent=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\app\Anaconda3\envs\drug\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Abs_nm'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 11
#       8 titles=('Initial dataset', 'Final dataset')
# ...

# %% [markdown]
# ### CD1

# %%
a4_dims = (25, 8)

fig, axs = plt.subplots(ncols=2, figsize=a4_dims)
fig.suptitle('CD1', fontsize=60)

datasets=(df, df_aug)
i=0
titles=('Initial dataset', 'Final dataset')
for dataset in datasets :

    CD1 = dataset.loc[dataset['CD1_nm'] != "None"]
    c=CD1['CD1_nm'].astype(float).tolist()
    sns.violinplot(data=c, inner=None, color='0.9', ax=axs[i]).set(title=titles[i])
    sns.swarmplot (data=c, color="steelblue", edgecolor="gray", size=9, ax=axs[i])
    i=+1 

fig.savefig('CD1.png', transparent=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\app\Anaconda3\envs\drug\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'CD1_nm'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 11
#       8 titles=('Initial dataset', 'Final dataset')
# ...

# %% [markdown]
# ### CD2

# %%
a4_dims = (25, 8)

fig, axs = plt.subplots(ncols=2, figsize=a4_dims)
fig.suptitle('CD2', fontsize=60)

datasets=(df, df_aug)
i=0
titles=('Initial dataset', 'Final dataset')
for dataset in datasets :

    CD2 = dataset.loc[dataset['CD2_nm'] != "None"]
    c=CD2['CD2_nm'].astype(float).tolist()
    sns.violinplot(data=c, inner=None, color='0.9', ax=axs[i]).set(title=titles[i])
    sns.swarmplot (data=c, color="steelblue", edgecolor="gray", size=9, ax=axs[i])
    i=+1 

fig.savefig('CD2.png', transparent=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\app\Anaconda3\envs\drug\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'CD2_nm'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 11
#       8 titles=('Initial dataset', 'Final dataset')
# ...

# %% [markdown]
# ### Reaction Time

# %%
df['time_min'].value_counts().index
# Out:
# Float64Index([ 120.0, 1440.0,  600.0,  180.0,   60.0,   20.0,  360.0,  720.0,
#                 15.0,   90.0,   10.0,   30.0,  240.0, 1200.0, 2880.0,   25.0,
#                960.0,  480.0, 1080.0],
#              dtype='float64')

# %%
df['time_min'].value_counts()
# Out:
# 120.0     23
# 1440.0    16
# 600.0     15
# 180.0     13
# 60.0      11
# 20.0      10
# 360.0      9
# 720.0      6
# 15.0       6
# 90.0       6
# 10.0       4
# 30.0       3
# 240.0      2
# 1200.0     1
# 2880.0     1
# 25.0       1
# 960.0      1
# 480.0      1
# 1080.0     1
# Name: time_min, dtype: int64

# %%
a4_dims = (300, 100)

fig, ax = plt.subplots(figsize=a4_dims)
sns.set(font_scale=30)
ax = sns.barplot(x=df['time_min'].value_counts().index, y=df['time_min'].value_counts()).set(title = 'time_min', ylabel='Frequency')
# fig.savefig('time.png', transparent=True)

# %% [markdown]
# ### Metal

# %%
df['metal'].value_counts()
# Out:
# gold         60
# silver       23
# palladium    21
# ruthenium    14
# platinum      9
# copper        2
# iridium       1
# Name: metal, dtype: int64

# %%
a4_dims = (300, 100)

fig, ax = plt.subplots(figsize=a4_dims)
sns.set(font_scale=30)

ax = sns.barplot(x=df['metal'].value_counts().index, y=df['metal'].value_counts()).set(title = 'metal', ylabel='Frequency')

# %% [markdown]
# ### Ligand

# %%
df['ligand'].value_counts()
# Out:
# L-cysteine                12
# None                      10
# L-glutathione              5
# CO/styrene copolymers2     5
# CO/styrene copolymers1     5
#                           ..
# Cinchonine                 1
# S-proline                  1
# CTAB                       1
# PVP                        1
# CD–SA–PAMAM-1.2            1
# Name: ligand, Length: 66, dtype: int64

# %%
'''
a4_dims = (300, 100)

fig, ax = plt.subplots(figsize=a4_dims)
sns.set(font_scale=2)

ax = sns.barplot(x=df['ligand'].value_counts().index, y=df['ligand'].value_counts()).set(title = 'ligand', ylabel='Frequency')
'''
# Out:
# "\na4_dims = (300, 100)\n\nfig, ax = plt.subplots(figsize=a4_dims)\nsns.set(font_scale=2)\n\nax = sns.barplot(x=df['ligand'].value_counts().index, y=df['ligand'].value_counts()).set(title = 'ligand', ylabel='Frequency')\n"
