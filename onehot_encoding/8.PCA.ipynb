# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.datasets import load_iris

# Load iris dataset as an example
df=pd.read_csv('./dataset_augmented_all.csv')
df
# Out:
#      Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  atomic_number  radius_pm  \
# 0               0             0           0        0.90070  -0.626518
# 1               1             1           1        0.90070  -0.626518
# 2               2             2           2       -1.03686  -0.252283
# 3               3             3           3       -1.03686  -0.252283
# 4               4             4           4        0.90070  -0.626518
# ..            ...           ...         ...            ...        ...
# 196           196           196         196       -1.03686  -0.252283
# 197           197           197         197       -1.03686  -0.252283
# 198           198           198         198       -1.03686  -0.252283
# 199           199           199         199       -1.03686  -0.252283
# 200           200           200         200       -1.03686  -0.252283
#
#      oxid_state  relativistic  metal_amount_mmol  num of group    spcaer  ...  \
# 0      0.980887      0.900450          -0.454943     -0.280991 -0.526910  ...
# 1      0.980887      0.900450          -0.454943     -0.280991 -0.526910  ...
# 2     -0.853143     -1.110555           1.601355      0.049297 -0.526910  ...
# 3     -0.853143     -1.110555           1.768534     -0.280991 -0.526910  ...
# 4      0.980887      0.900450          -0.454943      0.049297 -0.526910  ...
# ..          ...           ...                ...           ...       ...  ...
# 196   -0.853143     -1.110555          -0.265474     -0.115847 -0.742392  ...
# 197   -0.853143     -1.110555           0.570420     -0.115847 -0.526910  ...
# 198   -0.853143     -1.110555           0.570420     -0.115847 -0.526910  ...
# 199   -0.853143     -1.110555           0.570420     -0.115847 -0.526910  ...
# 200   -0.853143     -1.110555           0.570420     -0.115847 -0.526910  ...
#
#      aromaticity1  sol1_vol_mL   protic2  polarity index 2  aromaticity2  \
# 0       -0.070711    -0.124583 -0.537086         -0.793018     -0.240613
# 1       -0.070711    -0.104117 -0.537086         -0.793018     -0.240613
# 2       -0.070711    -0.175747 -0.537086         -0.793018     -0.240613
# 3       -0.070711    -0.032487 -0.537086         -0.793018     -0.240613
# 4       -0.070711    -0.124583 -0.537086         -0.793018     -0.240613
# ..            ...          ...       ...               ...           ...
# 196     -0.070711    -0.605526 -0.537086         -0.793018     -0.240613
# 197     -0.070711    -0.175747  1.861899          1.679991     -0.240613
# 198     -0.070711    -0.175747  1.861899          1.679991     -0.240613
# 199     -0.070711    -0.175747  1.861899          1.679991     -0.240613
# 200     -0.070711    -0.175747  1.861899          1.679991     -0.240613
#
#      solv2_vol_mL  time_min    temp_c   size_nm  g_factor*10^4
# 0       -0.523310  0.680663 -0.997007  3.060000       0.000000
# 1       -0.523310  0.680663 -0.997007  1.000000       0.757989
# 2       -0.523310 -0.593509 -0.997007  1.000000       0.583069
# 3       -0.523310 -0.593509 -0.997007  2.370000       0.000000
# 4       -0.523310  0.680663 -0.997007  4.000000      15.151515
# ..            ...       ...       ...       ...            ...
# 196     -0.523310  0.217328 -0.176375  2.066667       2.000000
# 197     -0.004855 -0.535592 -0.176375  1.050000      15.000000
# 198     -0.004855 -0.535592 -0.176375  1.300000      10.000000
# 199     -0.004855 -0.535592 -0.176375  1.050000       7.000000
# 200     -0.004855 -0.535592 -0.176375  1.300000       3.000000
#
# [201 rows x 29 columns]

# %%
input_col=[col for col in df.columns]
input_col.remove('Unnamed: 0')
input_col.remove('Unnamed: 0.1')
input_col.remove('Unnamed: 0.2')
input_col.remove('size_nm')
input_col.remove('g_factor*10^4')


input_col
# Out:
# ['atomic_number',
#  'radius_pm',
#  'oxid_state',
#  'relativistic',
#  'metal_amount_mmol',
#  'num of group',
#  'spcaer',
#  'anchoring_group',
#  'chirality type',
#  'hydrogen bond',
#  'aromaticity',
#  'ligand_amount_mmol',
#  'redu_num',
#  'reductant_amount_mmol',
#  'protic1',
#  'polarity index1',
#  'aromaticity1',
#  'sol1_vol_mL',
#  'protic2',
#  'polarity index 2',
#  'aromaticity2',
#  'solv2_vol_mL',
#  'time_min',
#  'temp_c']

# %%
input_col = ['atomic_number',
 'radius_pm',
 'oxid_state',
 'relativistic',
 'metal_amount_mmol',
 'num of group',
 'spcaer',
 'anchoring_group',
 'chirality type',
 'hydrogen bond',
 'aromaticity',
 'ligand_amount_mmol'
]

input_col
# Out:
# ['atomic_number',
#  'radius_pm',
#  'oxid_state',
#  'relativistic',
#  'metal_amount_mmol',
#  'num of group',
#  'spcaer',
#  'anchoring_group',
#  'chirality type',
#  'hydrogen bond',
#  'aromaticity',
#  'ligand_amount_mmol']

# %%
X=np.array(df[input_col])
X
# Out:
# array([[ 0.90070031, -0.62651772,  0.98088678, ...,  1.04582503,
#         -0.74708737, -0.19045691],
#        [ 0.90070031, -0.62651772,  0.98088678, ...,  1.04582503,
#         -0.74708737, -0.19045691],
#        [-1.03685969, -0.25228277, -0.85314338, ...,  1.04582503,
#         -0.74708737,  0.02943235],
#        ...,
#        [-1.03685969, -0.25228277, -0.85314338, ...,  1.04582503,
#         -0.74708737, -0.20544936],
#        [-1.03685969, -0.25228277, -0.85314338, ...,  1.04582503,
#         -0.74708737, -0.33038644],
#        [-1.03685969, -0.25228277, -0.85314338, ...,  1.04582503,
#         -0.74708737, -0.33038644]])

# %%
# Perform PCA with two components
pca = PCA(n_components=3)
X_pca = pca.fit_transform(X)
print(X_pca)
print(pca.components_)
print(pca.explained_variance_ratio_)
# Out:
# [[-2.04127885 -0.67956802 -0.41752415]
#  [-2.04127885 -0.67956802 -0.41752415]
#  [ 0.55514891 -2.05589732  1.44239146]
#  [ 0.48629663 -2.0773028   1.68965044]
#  [-1.97124961 -0.64219801 -0.54757826]
#  [-1.97124961 -0.64219801 -0.54757826]
#  [-1.97124961 -0.64219801 -0.54757826]
#  [ 1.42075338 -0.51473879 -0.34741602]
#  [-1.09422437  1.10324732 -0.87942977]
#  [-2.01124783 -0.53050351  0.30690095]
#  [-2.01124783 -0.53050351  0.30690095]
#  [-1.73551974  2.87913958  2.30563558]
#  [-1.74797634  2.81546424  1.74895086]
#  [-1.74901644  2.8101475   1.70246896]
#  [-1.99418524 -0.73343812 -0.81492993]
#  [-1.20447746  0.41595022 -0.72226306]
#  [-1.99810978 -0.71204879 -0.72112336]
#  [-1.98889155 -0.74782731 -0.84754044]
#  [ 0.53570233 -2.23375787  0.65259695]
#  [ 0.53570233 -2.23375787  0.65259695]]
# [[-0.42396184  0.42391265 -0.38148226 -0.41531792  0.01469639  0.21202535
#   -0.12223776  0.29451965  0.20522625 -0.24404305  0.25829946 -0.08537371]
#  [ 0.29112778  0.17387737  0.27268989  0.30780326  0.07512463  0.11314401
#    0.37081978  0.34413937 -0.00790721 -0.45552299  0.42704895  0.22713351]
#  [-0.18865928 -0.11077169  0.09929329 -0.19335952  0.65678068 -0.39376076
#   -0.03537129 -0.12121671  0.2267001  -0.08219229  0.0206851   0.49392394]]
# [0.29449867 0.1863364  0.13019736]

# %%
fig = plt.figure(figsize=(12, 12),dpi=150)
plt.style.use('default')
ax = fig.add_subplot(projection='3d')
cax=ax.scatter(X_pca[:,0] , X_pca[:,1] , X_pca[:,2], marker='o', c=df['g_factor*10^4'], cmap='winter')
plt.colorbar(cax, label='g_factor*10^4',fraction = 0.03, pad = 0.1)
ax.set_title('Principle Component Analysis',size=15)
ax.set(xlabel='Component 1 (29.45%)',ylabel='Component 2 (18.63%)',zlabel='Component 3 (13.02%)')
fig.savefig('PCA.svg',dpi=150,format='svg')

# %%
fig,(ax1,ax2,ax3) = plt.subplots(3,1 ,figsize=(7,15))
plt.style.use('default')

ax1.scatter(X_pca[:,0] , X_pca[:,1] ,marker='o', c=df['g_factor*10^4'], cmap='winter')
ax1.set(xlabel='component1',ylabel='component2')

ax2.scatter(X_pca[:,0] , X_pca[:,2] ,marker='o', c=df['g_factor*10^4'], cmap='winter')
ax2.set(xlabel='component1',ylabel='component3')

ax3.scatter(X_pca[:,1] , X_pca[:,2] ,marker='o', c=df['g_factor*10^4'], cmap='winter')
ax3.set(xlabel='component2',ylabel='component3')
# Out:
# [Text(0.5, 0, 'component2'), Text(0, 0.5, 'component3')]

# %%
X_pdf=pd.DataFrame(X_pca)
ind=pd.DataFrame({'index':range(130)})
X_pdf=pd.concat([ind,X_pdf],axis=1)

#region1
re1 = X_pdf[(X_pdf[0] <= -1.8) & (X_pdf[0] >= -2.3) & (X_pdf[1] <= 0) & (X_pdf[1] >= -1.9 ) & (X_pdf[2] <= 0) & (X_pdf[2] >= -1 )]

#region2
re2 = X_pdf[(X_pdf[0] <= 5.5) & (X_pdf[0] >= 3) & (X_pdf[1] <= 0) & (X_pdf[1] >= -2 ) ]

#region3
re3 = X_pdf[(X_pdf[0] <= 4) & (X_pdf[0] >= 2) & (X_pdf[1] <= 4) & (X_pdf[1] >= 0)]

#region4
re4 = X_pdf[(X_pdf[0] <= 0) & (X_pdf[0] >= -1) & (X_pdf[1] <= 2) & (X_pdf[1] >= -1 )]


print(re4)
# Out:
#      index         0         1         2
# 39    39.0 -0.811157  1.497898 -0.631222
# 40    40.0 -0.811157  1.497898 -0.631222
# 150    NaN -0.605320  1.316540 -0.888205
# 151    NaN -0.605320  1.316540 -0.888205
# 184    NaN -0.626824  1.263859  0.840546
